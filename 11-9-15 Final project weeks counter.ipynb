# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import NFL_api
import time
import pickle

# %%
f= open('player_def_2015_1-8.pickle')
player_stat = pickle.load(f)
f.close()

g=open('team_def_2015_1-8.pickle')
team_stat = pickle.load(g)
g.close()

h=open('injuries_2015_1-8.pickle')
injuries_df = pickle.load(h)
h.close()

# %%
player_stat.columns
# Out:
# Index([       u'game_id',      u'scheduled',            u'ast',
#                    u'bk',           u'comb',      u'force_fum',
#               u'fum_rec',         u'fum_td',             u'id',
#                   u'int',         u'int_lg',         u'int_td',
#               u'int_yds',         u'jersey',         u'market',
#              u'misc_ast',      u'misc_comb', u'misc_force_fum',
#          u'misc_fum_rec',    u'misc_tackle',           u'name',
#                    u'pd',       u'position',             u'qh',
#                  u'sack',       u'sack_yds',           u'sfty',
#              u'sfty_1pt',         u'sp_ast',        u'sp_comb',
#          u'sp_force_fum',     u'sp_fum_rec',      u'sp_tackle',
#                u'tackle',      u'team_name',          u'tlost',
#              u'week_num',       u'year_num'],
#       dtype='object')

# %%
player_stat.groupby(['name']).get_group('Erin Henderson')
# Out:
#                                  game_id                  scheduled  ast  bk  \
# 32  8e72ff56-7740-4fe4-b818-78344716abe0  2015-09-22T00:30:00+00:00    0   0
# 4   8554df33-0c28-46bd-80ff-9abdf3fa8b96  2015-09-27T17:00:00+00:00    0   0
# 6   f65cb36f-2f23-4ab5-9c6c-bab29678a6ad  2015-10-18T17:00:00+00:00    0   0
# 19  fadd8069-5b74-4970-8149-592f28e30493  2015-10-25T17:00:00+00:00    0   0
# 34  dff96fb5-52cc-4e8e-a155-e69d830b5e20  2015-11-01T21:05:00+00:00    0   0
#
#     comb  force_fum  fum_rec  fum_td                                    id  \
# 32     0          0        0       0  0612e146-6fa8-4770-a3a7-a142e46678cd
# 4      0          0        0       0  0612e146-6fa8-4770-a3a7-a142e46678cd
# 6      0          0        0       0  0612e146-6fa8-4770-a3a7-a142e46678cd
# 19     0          0        0       0  0612e146-6fa8-4770-a3a7-a142e46678cd
# 34     0          0        0       0  0612e146-6fa8-4770-a3a7-a142e46678cd
#
#     int    ...     sp_ast  sp_comb  sp_force_fum  sp_fum_rec sp_tackle  \
# 32    0    ...          0        1             0           0         1
# 4     0    ...          0        1             0           0         1
# 6     0    ...          1        1             0           0         0
# 19    0    ...          0        1             0           0         1
# 34    0    ...          0        4             0           0         4
#
#     tackle  team_name  tlost  week_num  year_num
# 32       0       Jets      0         2      2015
# 4        0       Jets      0         3      2015
# 6        0       Jets      0         6      2015
# 19       0       Jets      0         7      2015
# 34       0       Jets      0         8      2015
#
# [5 rows x 38 columns]

# %%
injuries_df.columns
# Out:
# Index([    u'description',         u'game_id',     u'game_status',
#                     u'id',   u'jersey_number',          u'market',
#                   u'name',       u'name_abbr',       u'name_full',
#                  u'notes',          u'played',        u'position',
#        u'practice_status',      u'start_date',         u'started',
#                 u'status',        u'week_num',        u'year_num'],
#       dtype='object')

# %%
for player in player_stat['name']:
    for week in player_stat[player_stat['name']==player]['week_num']:
        if player_stat[(injury_df['name_full']==player)&(injury_df['week_num']==week+1):
            player_stat[(player_stat['name']==player)&(player_stat['week_num']==week)]['injured?'] = 1
        else:
            player_stat[(player_stat['name']==player)&(player_stat['week_num']==week)]['injured?'] = 0
# Out:
#   File "<ipython-input-6-b966c7a5e47e>", line 4
#     player_stat[(player_stat['name']==player)&(player_stat['week_num']==week)]['injured?'] = 1
#                                                                                            ^
# SyntaxError: invalid syntax

# %%
player_stat[(player_stat['name']=='Erin Henderson')&(player_stat['week_num']==6)]['injured?']=1
# Out:
# /Users/ericalonas/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
player_stat.reset_index(drop=True, inplace=True)

# %%
for i in player_stat.index:
    name = player_stat.ix[i, 'name']
    week = player_stat.ix[i, 'week_num']
    if (len(injuries_df[(injuries_df['name_full']==name) & (injuries_df['week_num']==week+1)]) > 0):
        player_stat.loc[i,'injured?']=1
    #elif((len(injuries_df[(injuries_df['name_full']==name) & (injuries_df['week_num']==week)]) > 0)):
        #player_stat.loc[i,'injured?']=2
    else:
        player_stat.loc[i,'injured?']=0

# %%
player_stat['injured?'].value_counts()
# Out:
# 0    4225
# 1     572
# dtype: int64

# %%
player_stat[['name','week_num', 'tackle','injured?']]
# Out:
#                     name  week_num  tackle  injured?
# 0          Geneo Grissom         1       0         0
# 1             Nate Ebner         1       0         0
# 2            Alan Branch         1       2         0
# 3            Matt Slater         1       0         0
# 4        Jonathan Freeny         1       0         0
# 5          Rob Ninkovich         1       3         0
# 6             Jerod Mayo         1       1         0
# 7         Rob Gronkowski         1       0         0
# 8         Devin McCourty         1       5         0
# 9           Tarell Brown         1       2         0
# 10         Jamie Collins         1       4         0
# 11         Patrick Chung         1       4         0
# 12        Malcolm Butler         1       3         0
# 13      Bradley Fletcher         1       5         0
# 14        Sealver Siliga         1       3         0
# 15          Duron Harmon         1       3         0
# 16         Jabaal Sheard         1       2         0
# 17      Dont'a Hightower         1       8         0
# 18        Chandler Jones         1       2         0
# 19          Malcom Brown         1       1         0
# 20        Vince Williams         1       0         0
# 21       Shamarko Thomas         1       1         0
# 22          Jarvis Jones         1       1         0
# 23        James Harrison         1       2         0
# 24    Alvin 'Bud' Dupree         1       2         0
# 25          Cortez Allen         1       5         1
# 26         Roosevelt Nix         1       0         0
# 27      Lawrence Timmons         1       3         0
# 28          Ryan Shazier         1       6         1
# 29      Daniel McCullers         1       1         0
# ...                  ...       ...     ...       ...
# 4767        Luke Kuechly         8      11         0
# 4768        Roman Harper         8      11         0
# 4769           Kony Ealy         8       2         0
# 4770          Ed Dickson         8       0         0
# 4771        Griff Whalen         8       0         0
# 4772       Zurlon Tipton         8       0         0
# 4773         Andrew Luck         8       0         0
# 4774         David Parry         8       3         0
# 4775           Joe Reitz         8       0         0
# 4776        Dwayne Allen         8       0         0
# 4777         Josh Thomas         8       0         0
# 4778          Mike Adams         8       7         0
# 4779          Pat McAfee         8       0         0
# 4780       Hugh Thornton         8       0         0
# 4781       Bjoern Werner         8       1         0
# 4782       Andre Johnson         8       0         0
# 4783         Erik Walden         8       1         0
# 4784       Colt Anderson         8       0         0
# 4785          Billy Winn         8       0         0
# 4786          Trent Cole         8       1         0
# 4787      Henry Anderson         8       2         0
# 4788          Greg Toler         8       7         0
# 4789       Dwight Lowery         8       4         0
# 4790        Vontae Davis         8       2         0
# 4791     Jerrell Freeman         8      11         0
# 4792     D'Qwell Jackson         8       4         0
# 4793    Kendall Langford         8       0         0
# 4794       Darius Butler         8       4         0
# 4795       Robert Mathis         8       3         0
# 4796        Coby Fleener         8       0         0
#
# [4797 rows x 4 columns]

# %%
from sklearn.linear_model import LogisticRegressionCV
rgr = LogisticRegressionCV(cv=10)
rgr.fit(player_stat['tackle'].get_values().reshape(4797,1), player_stat['injured?'].get_values())
# Out:
# LogisticRegressionCV(Cs=10, class_weight=None, cv=10, dual=False,
#            fit_intercept=True, intercept_scaling=1.0, max_iter=100,
#            multi_class='ovr', n_jobs=1, penalty='l2', refit=True,
#            scoring=None, solver='lbfgs', tol=0.0001, verbose=0)

# %%
from sklearn.metrics import confusion_matrix
rgr.predict(player_stat['tackle'].get_values().reshape(4797,1))
# Out:
# array([False, False, False, ..., False, False, False], dtype=bool)

# %%
pd.rolling_mean(player_stat['tackle'],2)
# Out:
# (4797,)

# %%
test = player_stat.groupby(['name']).get_group('Erin Henderson')['sp_comb'].cumsum()
player_stat.groupby(['name']).get_group('Erin Henderson').join(test, how='outer', rsuffix='_cum')


test2 = pd.rolling_mean(player_stat.groupby(['name']).get_group('Erin Henderson')['sp_comb'],3)
test2.name='sp_comb'
test2.fillna(0, inplace=True)
#player_stat.groupby(['name']).get_group('Erin Henderson').join(test2, how='outer', rsuffix='_ravg')

# %%
stat_list=['tackle']

groups = player_stat.groupby(['name'])

for player in player_stat.name:
    for stat in stat_list:
        group=groups.get_group(name)
        cum_sum = groups.get_group(player)[stat].cumsum()
        group.join(cum_sum, how='outer', rsuffix='_cum')
        roll_avg = pd.rolling_mean(groups.get_group(player)[stat],3)
        roll_avg.name = '%s_r_avg' %(stat)
        roll_avg.fillna(0,inplace=True)
        group.join(roll_avg, how='outer', rsuffix='_ravg')

groups.get_group('Erin Henderson').columns
# Out:
# Index([       u'game_id',      u'scheduled',            u'ast',
#                    u'bk',           u'comb',      u'force_fum',
#               u'fum_rec',         u'fum_td',             u'id',
#                   u'int',         u'int_lg',         u'int_td',
#               u'int_yds',         u'jersey',         u'market',
#              u'misc_ast',      u'misc_comb', u'misc_force_fum',
#          u'misc_fum_rec',    u'misc_tackle',           u'name',
#                    u'pd',       u'position',             u'qh',
#                  u'sack',       u'sack_yds',           u'sfty',
#              u'sfty_1pt',         u'sp_ast',        u'sp_comb',
#          u'sp_force_fum',     u'sp_fum_rec',      u'sp_tackle',
#                u'tackle',      u'team_name',          u'tlost',
#              u'week_num',       u'year_num',       u'injured?'],
#       dtype='object')
