# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import NFL_api
import time
import pickle

# %%
h=open('injuries_2015_1-8.pickle')
injuries_df = pickle.load(h)
h.close()

# %%
injuries_df.description.value_counts()
# Out:
# Knee                           367
# Ankle                          249
# Hamstring                      234
# Shoulder                       153
# Groin                          101
# Concussion                      98
# Calf                            87
# Hip                             83
# Foot                            77
# Back                            62
# Hand                            41
# Illness                         38
# Toe                             34
# Neck                            32
# Elbow                           32
# Not Injury Related              32
# Thigh                           30
# Ribs                            29
# Rest                            20
# Finger                          20
# Thumb                           20
# Quadricep                       13
# NIR                             13
# Abdomen                         11
# Quad                            11
# Chest                           11
# Right Elbow                      9
# ...

# %%
injuries_df.reset_index(drop=True, inplace=True)

a = injuries_df.loc[:,'description']=='Not Injury Related'
injuries_df.loc[a.get_values()]
# Out:
#              description                               game_id game_status  \
# 81    Not Injury Related  83b72efe-7955-4fa4-9149-9eaccbbf0f20         PRO
# 396   Not Injury Related  f325594a-cd1d-43b3-b091-035cfa4d32b1         PRO
# 438   Not Injury Related  c3b00d9f-a539-4b66-b8f5-22729a611912         PRO
# 882   Not Injury Related  02090d42-6e9d-49ef-84fd-cf8211fb6154         PRO
# 884   Not Injury Related  02090d42-6e9d-49ef-84fd-cf8211fb6154         PRO
# 900   Not Injury Related  50e5db1c-b116-4cf9-8fd4-bba6c425278d         PRO
# 912   Not Injury Related  92d36a4a-8fcb-4418-bab7-ff6daf0ccc17         PRO
# 958   Not Injury Related  fafafeeb-bbaf-4a46-a978-73f7c4b11ee3         PRO
# 1097  Not Injury Related  89e85ffb-a815-4b8a-b507-6038244acbe7         UNK
# 1098  Not Injury Related  89e85ffb-a815-4b8a-b507-6038244acbe7         UNK
# 1151  Not Injury Related  c537b7f3-0069-4a07-80d5-4108cd221b6a         PRO
# ...

# %%
injuries_df.description.value_counts()
# Out:
# Knee                           367
# Ankle                          249
# Hamstring                      234
# Shoulder                       153
# Groin                          101
# Concussion                      98
# Calf                            87
# Hip                             83
# Foot                            77
# Back                            62
# Hand                            41
# Illness                         38
# Toe                             34
# Neck                            32
# Elbow                           32
# Not Injury Related              32
# Thigh                           30
# Ribs                            29
# Rest                            20
# Finger                          20
# Thumb                           20
# Quadricep                       13
# NIR                             13
# Abdomen                         11
# Quad                            11
# Chest                           11
# Right Elbow                      9
# ...
